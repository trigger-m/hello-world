# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as pit

x=np.random.rand(100)
y=np.random.rand(100)

pit.scatter(x,y)
pit.title("scatterplot1")
pit.xlabel("x axis")
pit.ylabel("y")
